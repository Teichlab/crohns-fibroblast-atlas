# %%
# %matplotlib inline
import pycistarget
pycistarget.__version__

import os
import glob
import pandas as pd
import matplotlib.pyplot as plt

# Load cistarget functions
from pycistarget.motif_enrichment_cistarget import *

import pyranges as pr
from pycistarget.utils import *

# %%
## Defining paths to input/output and cistarget db
input_dir = '/lustre/scratch126/cellgen/team205/sk29/matthias_fb/bulk_ATACseq_pipeline/tables/'
cistarget_db = '/lustre/scratch126/cellgen/team205/is10/fibroblasts/bulk_cytokines/cistarget/cistarget_db.regions_vs_motifs.rankings.feather'
motif_anno = '/nfs/team205/is10/resources/aerts_motifs/v10nr_clust_public/snapshots/motifs-v10-nr.hgnc-m0.00001-o0.0.tbl'
out_dir = '/lustre/scratch126/cellgen/team205/is10/fibroblasts/bulk_cytokines/cistarget/enrichment_padj0.01/'
os.makedirs(out_dir, exist_ok=True)

# %%
## Cutoffs for padj and logFC for DA peaks
padj_cutoff = 0.01
logFC_cutoff = 0.5

# %%
files = os.listdir(input_dir)
condition_paths = {}
for f in files:
    if ('differential' in f) and ('.csv' in f):
        condition_paths[f.split('.')[0]] = (input_dir + f)

# %%
condition_paths
# Out:
# {'differential_peak_table_FDR05_annotated_matched_Cytokine': '/lustre/scratch126/cellgen/team205/sk29/matthias_fb/bulk_ATACseq_pipeline/tables/differential_peak_table_FDR05_annotated_matched_Cytokine.csv',
#  'differential_peak_table_FDR05_annotated_matched_Cytokine + Belinostat': '/lustre/scratch126/cellgen/team205/sk29/matthias_fb/bulk_ATACseq_pipeline/tables/differential_peak_table_FDR05_annotated_matched_Cytokine + Belinostat.csv',
#  'differential_peak_table_FDR05_annotated_matched_Belinostat | cytokine': '/lustre/scratch126/cellgen/team205/sk29/matthias_fb/bulk_ATACseq_pipeline/tables/differential_peak_table_FDR05_annotated_matched_Belinostat | cytokine.csv'}

# %%
peaks[(peaks['FDR'] < padj_cutoff) & (peaks['logFC'] >= logFC_cutoff)]
# Out:
#       seqnames      start        end  width strand     logFC    logCPM  \
# 7         chr1   81440818   81441170    353      *  3.201871 -0.762567
# 37       chr10  123857827  123858764    938      *  1.929552  0.941050
# 88        chr6   29516141   29516601    461      *  1.863218  0.398044
# 505       chr8   58220489   58221914   1426      *  1.851944 -0.068502
# 558       chr8   58169465   58170306    842      *  1.655663  0.106460
# ...        ...        ...        ...    ...    ...       ...       ...
# 45956    chr16   70467894   70468771    878      *  1.188838 -0.973321
# 45969     chrX  144566744  144567028    285      *  1.445536 -1.636126
# 45971     chr7  157517944  157518938    995      *  1.331460 -1.202676
# 45973    chr17   79117525   79117755    231      *  1.183959 -1.094037
# 45976     chr5    1781816    1781993    178      *  1.620957 -1.691322
#
#                F  num.tests  num.up.logFC  ...    geneEnd  geneLength  \
# 7      59.333780          1             1  ...   81484722       70448
# 37     46.984255          1             1  ...  123887166        6958
# 88     41.502718          1             1  ...   29531240        2520
# 505    33.942401          3             3  ...   58243984       16407
# 558    31.250404          1             1  ...   58243984       16407
# ...          ...        ...           ...  ...        ...         ...
# 45956  11.124512          2             2  ...   70479681        5057
# 45969   9.841566          1             1  ...  145256208        8706
# 45971  11.874881          3             1  ...  157518658        2866
# 45973   9.840694          1             1  ...   79115580       26214
# 45976   9.839906          1             1  ...    1799750         922
#
#        geneStrand     geneId       transcriptId  distanceToTSS  \
# 7               1      23266  ENST00000674458.1          26543
# 37              2     119587  ENST00000481775.1          28402
# 88              1  100507362  ENST00000658484.1         -12120
# 505             2  107986945  ENST00000671135.1          22070
# 558             2  107986945  ENST00000671135.1          73678
# ...           ...        ...                ...            ...
# 45956           1     197258  ENST00000498702.1          -5854
# 45969           1     494118  ENST00000370493.4        -680475
# 45971           1  105375610  ENST00000648425.1           2151
# 45973           2     146713  ENST00000648001.1          -1945
# 45976           2      64979  ENST00000510999.1          17757
#
#                ENSEMBL        SYMBOL  \
# 7      ENSG00000117114        ADGRL2
# 37     ENSG00000121898         CPXM2
# 88     ENSG00000224582     LINC01015
# 505                NaN  LOC107986945
# 558                NaN  LOC107986945
# ...                ...           ...
# 45956  ENSG00000157353          FCSK
# 45969  ENSG00000203923       SPANXN1
# 45971              NaN  LOC105375610
# 45973  ENSG00000167281        RBFOX3
# 45976  ENSG00000171421        MRPL36
#
#                                           GENENAME  \
# 7           adhesion G protein-coupled receptor L2
# 37         carboxypeptidase X, M14 family member 2
# 88     long intergenic non-protein coding RNA 1015
# 505                   uncharacterized LOC107986945
# 558                   uncharacterized LOC107986945
# ...                                            ...
# 45956                                fucose kinase
# 45969                       SPANX family member N1
# 45971                 uncharacterized LOC105375610
# 45973                  RNA binding fox-1 homolog 3
# 45976          mitochondrial ribosomal protein L36
#
#                                           atac_peak
# 7                                               NaN
# 37         chr10:123858287-123858787,CPXM2,Intronic
# 88          chr6:29516029-29516529,LINC01015,Distal
# 505      chr8:58220688-58221188,LOC101929528,Distal
# 558    chr8:58169784-58170284,LOC101929528,Intronic
# ...                                             ...
# 45956                                           NaN
# 45969                                           NaN
# 45971                                           NaN
# 45973                                           NaN
# 45976                                           NaN
#
# [1107 rows x 27 columns]

# %%
region_sets = {}

for cond in condition_paths.keys():
    peaks = pd.read_csv(condition_paths[cond])
    ## Up
    up = peaks[(peaks['FDR'] < padj_cutoff) & (peaks['logFC'] >= logFC_cutoff)]
    up_peaks=(up['seqnames'] + ":" +up['start'].astype(str) + '-' + up['end'].astype(str)).tolist()

    region_sets[(cond + '_up')] = pr.PyRanges(region_names_to_coordinates(up_peaks))

    ## Down
    down = peaks[(peaks['FDR'] < padj_cutoff) & (peaks['logFC'] < ((-1) * logFC_cutoff))]
    down_peaks=(down['seqnames'] + ":" +down['start'].astype(str) + '-' + down['end'].astype(str)).tolist() 

    region_sets[(cond + '_down')] = pr.PyRanges(region_names_to_coordinates(down_peaks))

# %%
region_sets
# Out:
# {'differential_peak_table_FDR05_annotated_matched_Cytokine_up': +--------------+-----------+-----------+
#  | Chromosome   | Start     | End       |
#  | (category)   | (int64)   | (int64)   |
#  |--------------+-----------+-----------|
#  | chr1         | 81440818  | 81441170  |
#  | chr1         | 209720330 | 209721193 |
#  | chr1         | 81424081  | 81424543  |
#  | chr1         | 81414458  | 81414870  |
#  | ...          | ...       | ...       |
#  | chrX         | 77362944  | 77363228  |
#  | chrX         | 151741713 | 151742023 |
#  | chrX         | 135225097 | 135225327 |
#  | chrX         | 144566744 | 144567028 |
#  +--------------+-----------+-----------+
#  Unstranded PyRanges object has 1,107 rows and 3 columns from 23 chromosomes.
#  For printing, the PyRanges was sorted on Chromosome.,
#  'differential_peak_table_FDR05_annotated_matched_Cytokine_down': +--------------+-----------+-----------+
#  | Chromosome   | Start     | End       |
#  | (category)   | (int64)   | (int64)   |
#  |--------------+-----------+-----------|
#  | chr1         | 175223806 | 175224344 |
#  | chr1         | 38194440  | 38195219  |
#  | chr1         | 237234991 | 237235633 |
#  | chr1         | 168623191 | 168623624 |
#  | ...          | ...       | ...       |
#  | chrX         | 65534451  | 65535160  |
#  | chrX         | 103918061 | 103919704 |
#  | chrX         | 37061083  | 37061333  |
#  | chrX         | 45802999  | 45803982  |
#  | chrY         | 18992770  | 18993027  |
#  | chrY         | 24368003  | 24368602  |
#  | chrY         | 25301540  | 25302124  |
#  +--------------+-----------+-----------+
#  Unstranded PyRanges object has 44,879 rows and 3 columns from 24 chromosomes.
#  For printing, the PyRanges was sorted on Chromosome.,
#  'differential_peak_table_FDR05_annotated_matched_Cytokine + Belinostat_up': +--------------+-----------+-----------+
#  | Chromosome   | Start     | End       |
#  | (category)   | (int64)   | (int64)   |
#  |--------------+-----------+-----------|
#  | chr1         | 81440818  | 81441170  |
#  | chr1         | 12027485  | 12027688  |
#  | chr1         | 176263004 | 176263178 |
#  | chr1         | 200915842 | 200916163 |
#  | ...          | ...       | ...       |
#  | chrX         | 40480487  | 40480742  |
#  | chrX         | 150315231 | 150315440 |
#  | chrX         | 43858190  | 43858559  |
#  | chrX         | 145625677 | 145625899 |
#  +--------------+-----------+-----------+
#  Unstranded PyRanges object has 1,393 rows and 3 columns from 23 chromosomes.
#  For printing, the PyRanges was sorted on Chromosome.,
#  'differential_peak_table_FDR05_annotated_matched_Cytokine + Belinostat_down': +--------------+-----------+-----------+
#  | Chromosome   | Start     | End       |
#  | (category)   | (int64)   | (int64)   |
#  |--------------+-----------+-----------|
#  | chr1         | 175223806 | 175224344 |
#  | chr1         | 48035361  | 48035738  |
#  | chr1         | 38194440  | 38195219  |
#  | chr1         | 19414489  | 19415169  |
#  | ...          | ...       | ...       |
#  | chrY         | 24368003  | 24368602  |
#  | chrY         | 24270821  | 24271691  |
#  | chrY         | 12448672  | 12449044  |
#  | chrY         | 18992770  | 18993027  |
#  +--------------+-----------+-----------+
#  Unstranded PyRanges object has 68,786 rows and 3 columns from 24 chromosomes.
#  For printing, the PyRanges was sorted on Chromosome.,
#  'differential_peak_table_FDR05_annotated_matched_Belinostat | cytokine_up': +--------------+-----------+-----------+
#  | Chromosome   | Start     | End       |
#  | (category)   | (int64)   | (int64)   |
#  |--------------+-----------+-----------|
#  | chr1         | 185284447 | 185285376 |
#  | chr2         | 74437367  | 74437611  |
#  | chr2         | 40346406  | 40347257  |
#  | chr2         | 114853717 | 114853917 |
#  | ...          | ...       | ...       |
#  | chr14        | 95085123  | 95085828  |
#  | chr16        | 16405431  | 16407046  |
#  | chr17        | 37751701  | 37751851  |
#  | chr19        | 43735942  | 43736560  |
#  +--------------+-----------+-----------+
#  Unstranded PyRanges object has 21 rows and 3 columns from 13 chromosomes.
#  For printing, the PyRanges was sorted on Chromosome.,
#  'differential_peak_table_FDR05_annotated_matched_Belinostat | cytokine_down': +--------------+-----------+-----------+
#  | Chromosome   | Start     | End       |
#  | (category)   | (int64)   | (int64)   |
#  |--------------+-----------+-----------|
#  | chr1         | 48035361  | 48035738  |
#  | chr1         | 164155270 | 164155851 |
#  | chr1         | 30675631  | 30676283  |
#  | chr1         | 20063795  | 20064408  |
#  | ...          | ...       | ...       |
#  | chrX         | 2664465   | 2665017   |
#  | chrX         | 100647043 | 100647458 |
#  | chrX         | 151697531 | 151697942 |
#  | chrX         | 131901531 | 131902248 |
#  +--------------+-----------+-----------+
#  Unstranded PyRanges object has 597 rows and 3 columns from 23 chromosomes.
#  For printing, the PyRanges was sorted on Chromosome.}

# %%
# Run
cistarget_dict = run_cistarget(ctx_db = cistarget_db,
                               region_sets = region_sets,
                               specie = 'homo_sapiens',
                               annotation_version = 'v10nr_clust',
                               path_to_motif_annotations = motif_anno,
                               auc_threshold = 0.005,
                               nes_threshold = 3.0,
                               rank_threshold = 0.05,
                               annotation = ['Direct_annot', 'Orthology_annot'],
                               n_cpu = 1,
                               _temp_dir='/lustre/scratch126/cellgen/team205/is10/tmp/')
# Out:
# 2023-11-28 22:05:22,446 cisTarget    INFO     Reading cisTarget database
# 2023-11-28 22:07:15,178 cisTarget    INFO     Running cisTarget for differential_peak_table_FDR05_annotated_matched_Cytokine_up which has 1356 regions
# 2023-11-28 22:07:43,761 cisTarget    INFO     Annotating motifs for differential_peak_table_FDR05_annotated_matched_Cytokine_up
# 2023-11-28 22:07:47,842 cisTarget    INFO     Getting cistromes for differential_peak_table_FDR05_annotated_matched_Cytokine_up
# 2023-11-28 22:07:48,024 cisTarget    INFO     Running cisTarget for differential_peak_table_FDR05_annotated_matched_Cytokine_down which has 57254 regions
# 2023-11-28 22:08:03,550 cisTarget    INFO     No enriched motifs found for differential_peak_table_FDR05_annotated_matched_Cytokine_down
# 2023-11-28 22:08:03,576 cisTarget    INFO     Running cisTarget for differential_peak_table_FDR05_annotated_matched_Cytokine + Belinostat_up which has 1682 regions
# 2023-11-28 22:08:18,098 cisTarget    INFO     Annotating motifs for differential_peak_table_FDR05_annotated_matched_Cytokine + Belinostat_up
# 2023-11-28 22:08:21,318 cisTarget    INFO     Getting cistromes for differential_peak_table_FDR05_annotated_matched_Cytokine + Belinostat_up
# 2023-11-28 22:08:21,413 cisTarget    INFO     Running cisTarget for differential_peak_table_FDR05_annotated_matched_Cytokine + Belinostat_down which has 87262 regions
# 2023-11-28 22:08:40,907 cisTarget    INFO     No enriched motifs found for differential_peak_table_FDR05_annotated_matched_Cytokine + Belinostat_down
# 2023-11-28 22:08:40,940 cisTarget    INFO     Running cisTarget for differential_peak_table_FDR05_annotated_matched_Belinostat | cytokine_up which has 24 regions
# 2023-11-28 22:08:57,684 cisTarget    INFO     Annotating motifs for differential_peak_table_FDR05_annotated_matched_Belinostat | cytokine_up
# 2023-11-28 22:09:01,097 cisTarget    INFO     Getting cistromes for differential_peak_table_FDR05_annotated_matched_Belinostat | cytokine_up
# 2023-11-28 22:09:01,529 cisTarget    INFO     Running cisTarget for differential_peak_table_FDR05_annotated_matched_Belinostat | cytokine_down which has 710 regions
# 2023-11-28 22:09:10,210 cisTarget    INFO     Annotating motifs for differential_peak_table_FDR05_annotated_matched_Belinostat | cytokine_down
# 2023-11-28 22:09:13,280 cisTarget    INFO     Getting cistromes for differential_peak_table_FDR05_annotated_matched_Belinostat | cytokine_down
# 2023-11-28 22:09:13,485 cisTarget    INFO     Done!

# %%
# Save
import pickle
with open((out_dir + 'cistarget_dict_NES3.0.pkl'), 'wb') as f:
  pickle.dump(cistarget_dict, f)

# %%
## Also exporting results in a table format:
motif_enrichment_dict = {key: cistarget_dict[key].motif_enrichment for key in cistarget_dict.keys()}
motif_enrichment_table=pd.concat([motif_enrichment_dict[key] for key in motif_enrichment_dict.keys()], axis=0, sort=False)
motif_enrichment_table.to_csv((out_dir + "cistarget_res_df_NES3.0.txt"), sep="\t")

# %%
cistarget_results(cistarget_dict, name="differential_peak_table_FDR05_annotated_matched_Cytokine_up")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="min-width: 80px;"></th>
#       <th style="min-width: 80px;">Logo</th>
#       <th style="min-width: 80px;">Region_set</th>
#       <th style="min-width: 80px;">Direct_annot</th>
#       <th style="min-width: 80px;">Orthology_annot</th>
#       <th style="min-width: 80px;">NES</th>
#       <th style="min-width: 80px;">AUC</th>
#       <th style="min-width: 80px;">Rank_at_max</th>
#       <th style="min-width: 80px;">Motif_hits</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>predrem__nrMotif404</th>
#       <td><img src="https://motifcollections.aertslab.org/v10nr_clust/logos/predrem__nrMotif404.png" width="200" ></td>
#       <td>differential_peak_table_FDR05_annotated_matched_Cytokine_up</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>5.834570</td>
#       <td>0.009876</td>
#       <td>3258.0</td>
#       <td>33</td>
#     </tr>
#     <tr>
#       <th>predrem__nrMotif1203</th>
#       <td><img src="https://motifcollections.aertslab.org/v10nr_clust/logos/predrem__nrMotif1203.png" width="200" ></td>
#       <td>differential_peak_table_FDR05_annotated_matched_Cytokine_up</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>5.817860</td>
#       <td>0.009853</td>
#       <td>11831.0</td>
#       <td>82</td>
#     </tr>
#     <tr>
#       <th>cisbp__M00569</th>
#       <td><img src="https://motifcollections.aertslab.org/v10nr_clust/logos/cisbp__M00569.png" width="200" ></td>
#       <td>differential_peak_table_FDR05_annotated_matched_Cytokine_up</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>5.567846</td>
#       <td>0.009503</td>
#       <td>15087.0</td>
#       <td>90</td>
#     </tr>
#     <tr>
#       <th>jaspar__MA0249.2</th>
#       <td><img src="https://motifcollections.aertslab.org/v10nr_clust/logos/jaspar__MA0249.2.png" width="200" ></td>
#       <td>differential_peak_table_FDR05_annotated_matched_Cytokine_up</td>
#       <td>NaN</td>
#       <td>TCF15, FERD3L, TCF21, TCF23, FIGLA, TWIST1, TCF24, HAND2, TWIST2, MSC, BHLHA9, HAND1, SCX</td>
#       <td>5.440159</td>
#       <td>0.009325</td>
#       <td>4635.0</td>
#       <td>41</td>
#     </tr>
#     <tr>
#       <th>cisbp__M00127</th>
#       <td><img src="https://motifcollections.aertslab.org/v10nr_clust/logos/cisbp__M00127.png" width="200" ></td>
#       <td>differential_peak_table_FDR05_annotated_matched_Cytokine_up</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>5.324768</td>
#       <td>0.009164</td>
#       <td>4357.0</td>
#       <td>34</td>
#     </tr>
#     <tr>
#       <th>flyfactorsurvey__CG16778_SANGER_5_FBgn0003715</th>
#       <td><img src="https://motifcollections.aertslab.org/v10nr_clust/logos/flyfactorsurvey__CG16778_SANGER_5_FBgn0003715.png" width="200" ></td>
#       <td>differential_peak_table_FDR05_annotated_matched_Cytokine_up</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>5.279683</td>
#       <td>0.009101</td>
#       <td>6091.0</td>
#       <td>56</td>
#     </tr>
#     <tr>
#       <th>hdpi__NR4A1</th>
#       <td><img src="https://motifcollections.aertslab.org/v10nr_clust/logos/hdpi__NR4A1.png" width="200" ></td>
#       <td>differential_peak_table_FDR05_annotated_matched_Cytokine_up</td>
#       <td>NR4A1</td>
#       <td>NaN</td>
#       <td>5.061827</td>
#       <td>0.008796</td>
#       <td>9890.0</td>
#       <td>72</td>
#     </tr>
#     <tr>
#       <th>cisbp__M00336</th>
#       <td><img src="https://motifcollections.aertslab.org/v10nr_clust/logos/cisbp__M00336.png" width="200" ></td>
#       <td>differential_peak_table_FDR05_annotated_matched_Cytokine_up</td>
#       <td>PAX6</td>
#       <td>NaN</td>
#       <td>5.056782</td>
#       <td>0.008789</td>
#       <td>16127.0</td>
#       <td>99</td>
#     </tr>
#     <tr>
#       <th>cisbp__M00748</th>
#       <td><img src="https://motifcollections.aertslab.org/v10nr_clust/logos/cisbp__M00748.png" width="200" ></td>
#       <td>differential_peak_table_FDR05_annotated_matched_Cytokine_up</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>5.040703</td>
#       <td>0.008767</td>
#       <td>4255.0</td>
#       <td>36</td>
#     </tr>
#     <tr>
#       <th>hdpi__USF1</th>
#       <td><img src="https://motifcollections.aertslab.org/v10nr_clust/logos/hdpi__USF1.png" width="200" ></td>
#       <td>differential_peak_table_FDR05_annotated_matched_Cytokine_up</td>
#       <td>USF1</td>
#       <td>NaN</td>
#       <td>5.007599</td>
#       <td>0.008720</td>
#       <td>1596.0</td>
#       <td>19</td>
#     </tr>
#     <tr>
#       <th>yetfasco__YGL071W_658</th>
#       <td><img src="https://motifcollections.aertslab.org/v10nr_clust/logos/yetfasco__YGL071W_658.png" width="200" ></td>
#       <td>differential_peak_table_FDR05_annotated_matched_Cytokine_up</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>4.922790</td>
#       <td>0.008602</td>
#       <td>13555.0</td>
#       <td>89</td>
#     </tr>
#     <tr>
#       <th>cisbp__M00577</th>
#       <td><img src="https://motifcollections.aertslab.org/v10nr_clust/logos/cisbp__M00577.png" width="200" ></td>
#       <td>differential_peak_table_FDR05_annotated_matched_Cytokine_up</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>4.853114</td>
#       <td>0.008505</td>
#       <td>5409.0</td>
#       <td>39</td>
#     </tr>
#     <tr>
#       <th>cisbp__M01738</th>
#       <td><img src="https://motifcollections.aertslab.org/v10nr_clust/logos/cisbp__M01738.png" width="200" ></td>
#       <td>differential_peak_table_FDR05_annotated_matched_Cytokine_up</td>
#       <td>NaN</td>
#       <td>BHLHE40</td>
#       <td>4.842394</td>
#       <td>0.008490</td>
#       <td>4539.0</td>
#       <td>38</td>
#     </tr>
#     <tr>
#       <th>cisbp__M01128</th>
#       <td><img src="https://motifcollections.aertslab.org/v10nr_clust/logos/cisbp__M01128.png" width="200" ></td>
#       <td>differential_peak_table_FDR05_annotated_matched_Cytokine_up</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>4.775871</td>
#       <td>0.008397</td>
#       <td>1641.0</td>
#       <td>21</td>
#     </tr>
#     <tr>
#       <th>cisbp__M00747</th>
#       <td><img src="https://motifcollections.aertslab.org/v10nr_clust/logos/cisbp__M00747.png" width="200" ></td>
#       <td>differential_peak_table_FDR05_annotated_matched_Cytokine_up</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>4.713131</td>
#       <td>0.008309</td>
#       <td>2203.0</td>
#       <td>27</td>
#     </tr>
#     <tr>
#       <th>cisbp__M00722</th>
#       <td><img src="https://motifcollections.aertslab.org/v10nr_clust/logos/cisbp__M00722.png" width="200" ></td>
#       <td>differential_peak_table_FDR05_annotated_matched_Cytokine_up</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>4.701150</td>
#       <td>0.008292</td>
#       <td>4499.0</td>
#       <td>32</td>
#     </tr>
#     <tr>
#       <th>cisbp__M00749</th>
#       <td><img src="https://motifcollections.aertslab.org/v10nr_clust/logos/cisbp__M00749.png" width="200" ></td>
#       <td>differential_peak_table_FDR05_annotated_matched_Cytokine_up</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>4.678766</td>
#       <td>0.008261</td>
#       <td>3076.0</td>
#       <td>35</td>
#     </tr>
#     <tr>
#       <th>cisbp__M00147</th>
#       <td><img src="https://motifcollections.aertslab.org/v10nr_clust/logos/cisbp__M00147.png" width="200" ></td>
#       <td>differential_peak_table_FDR05_annotated_matched_Cytokine_up</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>4.677505</td>
#       <td>0.008259</td>
#       <td>5714.0</td>
#       <td>50</td>
#     </tr>
#     <tr>
#       <th>cisbp__M00640</th>
#       <td><img src="https://motifcollections.aertslab.org/v10nr_clust/logos/cisbp__M00640.png" width="200" ></td>
#       <td>differential_peak_table_FDR05_annotated_matched_Cytokine_up</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>4.665839</td>
#       <td>0.008243</td>
#       <td>7578.0</td>
#       <td>52</td>
#     </tr>
#     <tr>
#       <th>cisbp__M01700</th>
#       <td><img src="https://motifcollections.aertslab.org/v10nr_clust/logos/cisbp__M01700.png" width="200" ></td>
#       <td>differential_peak_table_FDR05_annotated_matched_Cytokine_up</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>4.622962</td>
#       <td>0.008183</td>
#       <td>2927.0</td>
#       <td>27</td>

# %%
cistarget_results(cistarget_dict, name="differential_peak_table_FDR05_annotated_matched_Cytokine_down")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th style="min-width: 80px;"></th>
#       <th style="min-width: 80px;">Logo</th>
#       <th style="min-width: 80px;">Region_set</th>
#       <th style="min-width: 80px;">Direct_annot</th>
#       <th style="min-width: 80px;">Motif_similarity_annot</th>
#       <th style="min-width: 80px;">Orthology_annot</th>
#       <th style="min-width: 80px;">Motif_similarity_and_Orthology_annot</th>
#       <th style="min-width: 80px;">NES</th>
#       <th style="min-width: 80px;">AUC</th>
#       <th style="min-width: 80px;">Rank_at_max</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
# Also running a permissive analysis (NES > 0.1 instead of 3) to be used for more quantitative comparisons between classes
cistarget_dict_perm = run_cistarget(ctx_db = cistarget_db,
                               region_sets = region_sets,
                               specie = 'homo_sapiens',
                               annotation_version = 'v10nr_clust',
                               path_to_motif_annotations = motif_anno,
                               auc_threshold = 0.005,
                               nes_threshold = 0.1,
                               rank_threshold = 0.05,
                               annotation = ['Direct_annot', 'Orthology_annot'],
                               n_cpu = 1,
                               _temp_dir='/lustre/scratch126/cellgen/team205/is10/tmp/')
# Out:
# 2023-12-03 17:26:27,935 cisTarget    INFO     Reading cisTarget database
# 2023-12-03 17:27:54,715 cisTarget    INFO     Running cisTarget for differential_peak_table_FDR05_annotated_matched_Cytokine_up which has 1356 regions
# 2023-12-03 17:28:54,828 cisTarget    INFO     Annotating motifs for differential_peak_table_FDR05_annotated_matched_Cytokine_up
# 2023-12-03 17:29:06,079 cisTarget    INFO     Getting cistromes for differential_peak_table_FDR05_annotated_matched_Cytokine_up
# 2023-12-03 17:29:18,968 cisTarget    INFO     Running cisTarget for differential_peak_table_FDR05_annotated_matched_Cytokine_down which has 57254 regions
# 2023-12-03 17:45:05,613 cisTarget    INFO     Getting cistromes for differential_peak_table_FDR05_annotated_matched_Cytokine_down
# 2023-12-03 17:45:41,224 cisTarget    INFO     Running cisTarget for differential_peak_table_FDR05_annotated_matched_Cytokine + Belinostat_up which has 1682 regions
# 2023-12-03 17:47:32,044 cisTarget    INFO     Annotating motifs for differential_peak_table_FDR05_annotated_matched_Cytokine + Belinostat_up
# 2023-12-03 17:47:44,689 cisTarget    INFO     Getting cistromes for differential_peak_table_FDR05_annotated_matched_Cytokine + Belinostat_up
# 2023-12-03 17:48:07,483 cisTarget    INFO     Running cisTarget for differential_peak_table_FDR05_annotated_matched_Cytokine + Belinostat_down which has 87262 regions
# 2023-12-03 18:21:45,159 cisTarget    INFO     Annotating motifs for differential_peak_table_FDR05_annotated_matched_Cytokine + Belinostat_down
# 2023-12-03 18:23:25,185 cisTarget    INFO     Getting cistromes for differential_peak_table_FDR05_annotated_matched_Cytokine + Belinostat_down
# 2023-12-03 18:23:50,636 cisTarget    INFO     Running cisTarget for differential_peak_table_FDR05_annotated_matched_Belinostat | cytokine_up which has 24 regions
# 2023-12-03 18:24:14,794 cisTarget    INFO     Annotating motifs for differential_peak_table_FDR05_annotated_matched_Belinostat | cytokine_up
# 2023-12-03 18:24:19,969 cisTarget    INFO     Getting cistromes for differential_peak_table_FDR05_annotated_matched_Belinostat | cytokine_up
# 2023-12-03 18:24:22,100 cisTarget    INFO     Running cisTarget for differential_peak_table_FDR05_annotated_matched_Belinostat | cytokine_down which has 710 regions
# 2023-12-03 18:25:16,583 cisTarget    INFO     Annotating motifs for differential_peak_table_FDR05_annotated_matched_Belinostat | cytokine_down
# 2023-12-03 18:25:23,931 cisTarget    INFO     Getting cistromes for differential_peak_table_FDR05_annotated_matched_Belinostat | cytokine_down
# 2023-12-03 18:25:36,653 cisTarget    INFO     Done!

# %%
# Save
import pickle
with open((out_dir + 'cistarget_dict_NES0.1.pkl'), 'wb') as f:
  pickle.dump(cistarget_dict_perm, f)

# %%
## Also exporting results in a table format:
motif_enrichment_dict_perm = {key: cistarget_dict_perm[key].motif_enrichment for key in cistarget_dict_perm.keys()}
motif_enrichment_table_perm=pd.concat([motif_enrichment_dict_perm[key] for key in motif_enrichment_dict_perm.keys()], axis=0, sort=False)
motif_enrichment_table_perm.to_csv((out_dir + "cistarget_res_df_NES0.1.txt"), sep="\t")
