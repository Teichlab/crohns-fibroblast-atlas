# %%
# Load Ni's ArchR project folder and extract reduced dimensions

# %%
#library(tidyverse)
#library(RColorBrewer)
library(ArchR)
#library(Seurat)
#library(SingleCellExperiment)
library(anndata)
library(dplyr)
# Out:
#                                                    / |
#                                                  /    \
#             .                                  /      |.
#             \\\                              /        |.
#               \\\                          /           `|.
#                 \\\                      /              |.
#                   \                    /                |\
#                   \\#####\           /                  ||
#                 ==###########>      /                   ||
#                  \\##==......\    /                     ||
#             ______ =       =|__ /__                     ||      \\\
#         ,--' ,----`-,__ ___/'  --,-`-===================##========>
#        \               '        ##_______ _____ ,--,__,=##,__   ///
#         ,    __==    ___,-,__,--'#'  ==='      `-'    | ##,-/
#         -,____,---'       \\####\\________________,--\\_##,/
#            ___      .______        ______  __    __  .______
# ...

# %%
set.seed(1)
addArchRThreads(4)
addArchRGenome('hg38')
# Out:
# Setting default number of Parallel threads to 4.
#
# Setting default genome to Hg38.

# %%
# Load ArchR project, corresponding to Ni's run_archr.R script
proj = loadArchRProject(path="../20201116_scATAC_batch1_2/all")
#proj = loadArchRProject(path="../20220513_archr_scATAC/scatac")
# Out:
# Successfully loaded ArchRProject!
#
#
#                                                    / |
#                                                  /    \
#             .                                  /      |.
#             \\\                              /        |.
#               \\\                          /           `|.
#                 \\\                      /              |.
#                   \                    /                |\
#                   \\#####\           /                  ||
#                 ==###########>      /                   ||
#                  \\##==......\    /                     ||
#             ______ =       =|__ /__                     ||      \\\
#         ,--' ,----`-,__ ___/'  --,-`-===================##========>
#        \               '        ##_______ _____ ,--,__,=##,__   ///
#         ,    __==    ___,-,__,--'#'  ==='      `-'    | ##,-/
#         -,____,---'       \\####\\________________,--\\_##,/
# ...

# %%
slotNames(proj)
# Out:
#  [1] "projectMetadata"  "projectSummary"   "sampleColData"    "sampleMetadata"
#  [5] "cellColData"      "cellMetadata"     "reducedDims"      "embeddings"
#  [9] "peakSet"          "peakAnnotation"   "geneAnnotation"   "genomeAnnotation"
# [13] "imputeWeights"

# %%
proj@reducedDims
# Out:
# List of length 2
# names(2): IterativeLSI Harmony

# %%
getReducedDims(proj, "IterativeLSI")
# Out:
#                         LSI1      LSI2        LSI3        LSI4
# NX02#TGCATGAGTACCTATG-1 -4.832993 0.95684757   0.34210646 -1.33040875
# NX02#GCAGCTGCATGGAGGT-1 -4.730851 1.38116468   1.24624765  1.16105956
# NX02#ACATGGTCACAAGGGT-1 -4.964772 0.93572892  -0.10000531  0.14536142
# NX02#GCGTTGGCAACGTCGC-1 -5.019564 1.16083882   0.43976050 -0.34216993
# NX02#CACAGATTCGAGGCTC-1 -4.956693 1.05432524   1.12698833  0.79806264
# NX02#CCTTAATTCAGGAATA-1 -4.212407 0.12269840   0.84014656 -0.16133898
# NX02#GGGCCATTCCCACTTG-1 -4.843508 0.90970456  -0.15555085 -0.64216297
# NX02#GGCGTTGGTGCTTGAT-1 -4.977706 0.88880677   0.50805635 -0.51765608
# NX02#CGGACCACACAAGGGT-1 -4.972902 1.25317784   1.05033538  0.29674262
# NX02#TCAAGCATCTATCTAC-1 -4.899853 0.78195585   0.92915053 -1.22152471
# NX02#TGAGTCATCTAGTCGA-1 -4.886988 0.45581618  -0.45408973 -1.03851486
# NX02#CCGAAGCCAAACCTAC-1 -4.819683 0.43451908   0.42054886 -1.31027581
# ...

# %%
getReducedDims(proj, "Harmony")
# Out:
#                         LSI1      LSI2        LSI3          LSI4
# NX02#TGCATGAGTACCTATG-1 -4.839788  0.55286378  0.37016377   -1.286755946
# NX02#GCAGCTGCATGGAGGT-1 -4.739472  0.99514397  1.26824300    1.205501712
# NX02#ACATGGTCACAAGGGT-1 -4.968177  0.49772202 -0.06045173    0.187452536
# NX02#GCGTTGGCAACGTCGC-1 -5.027555  0.76863126  0.46384331   -0.297997906
# NX02#CACAGATTCGAGGCTC-1 -4.962011  0.63575000  1.15997104    0.841068628
# NX02#CCTTAATTCAGGAATA-1 -4.174232 -0.72490167  1.01793710   -0.137298866
# NX02#GGGCCATTCCCACTTG-1 -4.847984  0.48286133 -0.11977819   -0.599518800
# NX02#GGCGTTGGTGCTTGAT-1 -4.982595  0.46602962  0.54245660   -0.474832737
# NX02#CGGACCACACAAGGGT-1 -4.981229  0.86425711  1.07330957    0.341056360
# NX02#TCAAGCATCTATCTAC-1 -4.904624  0.35798803  0.96395323   -1.178756802
# NX02#TGAGTCATCTAGTCGA-1 -4.878985 -0.09399542 -0.37681478   -1.001294500
# NX02#CCGAAGCCAAACCTAC-1 -4.814588 -0.08666664  0.48816315   -1.271795615
# ...

# %%
#write.csv(getReducedDims(proj, "IterativeLSI"), file=gzfile("data/atac_IterativeLSI.csv.gz"))

# %%
# Write as .csv files
write.csv(getReducedDims(proj, "IterativeLSI"), file="data/atac_IterativeLSI.csv")
write.csv(getReducedDims(proj, "Harmony"), file="data/atac_IterativeLSI_harmony.csv")
